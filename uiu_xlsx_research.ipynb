# %%
import pandas as pd

df = pd.read_excel("final-exam-schedule_252_sose_notice-board.xlsx")
df.sort_values("Room")
df
# Out:
#      Dept.                Course Code  \
# 0     BSCE  ENG 101/ENG 1011/ENG 1105
# 1     BSCE                    CE 2201
# 2    BSCSE           CSE 4509/CSI 309
# 3    BSCSE           CSE 4509/CSI 309
# 4    BSCSE           CSE 4509/CSI 309
# ..     ...                        ...
# 473  BSCSE           PHY 105/PHY 2105
# 474  BSCSE           PHY 105/PHY 2105
# 475  BSCSE           PHY 105/PHY 2105
# 476  BSCSE           PHY 105/PHY 2105
# 477  BSEEE                   EEE 4331
#
#                                     Course Title Section Teacher  \
# 0                                      English I      CA    MFRK
# 1          Engineering Geology and Geomorphology       A    ShMS
# 2    Operating System Concepts/Operating Systems       A   SabAd
# 3    Operating System Concepts/Operating Systems       B    RbAn
# 4    Operating System Concepts/Operating Systems       C    ARnA
# ..                                           ...     ...     ...
# ...
